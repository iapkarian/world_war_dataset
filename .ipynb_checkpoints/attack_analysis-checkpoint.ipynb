# %%
import pandas as pd
from ggplot import *
import numpy as np
# %matplotlib inline

# Set ipython's max row display
pd.set_option('display.max_row', 1000)

# Set iPython's max column width to 50
pd.set_option('display.max_columns', 50)

# %%
df = pd.read_csv('world_war.csv')

# %% [markdown]
# ### Quick glance at the data

# %%
df.head(10)
# Out:
#                         Name    Year                            Location  \
# 0             Battle of Mons  1914.0                       Mons, Belgium
# 1            Battle of Liege  1914.0                      Liege, Belgium
# 2    Battle of the Frontiers  1914.0  Lorraine, the Ardennes and Belgium
# 3          Togoland Campaign  1914.0                     German Togoland
# 4              Battle of Cer  1914.0                        Cer Mountain
# 5       Battle of Tannenberg  1914.0            Allenstein, East Prussia
# 6  First Battle of the Marne  1914.0                  Marne River, Paris
# 7            Battle of Drina  1914.0                         Drina River
# 8      First Battle of Ypres  1914.0                      Ypres, Belgium
# 9          Siege of Tsingtao  1914.0                   Tsingtau, Germany
#
#          Assaulter        Defender      Assaulter_1     Assaulter_2  \
# 0    German Empire  British Empire              NaN             NaN
# 1    German Empire         Belgium              NaN             NaN
# 2          Belgium   German Empire           France  British Empire
# 3   British Empire   German Empire           France             NaN
# 4  Austria-Hungary          Serbia              NaN             NaN
# 5   Russian Empire   German Empire              NaN             NaN
# 6           France   German Empire   British Empire             NaN
# 7  Austria-Hungary          Serbia              NaN             NaN
# 8           France   German Empire          Belgium  British Empire
# 9   British Empire   German Empire  Empire of Japan             NaN
#
#         Defender_1 Defender_2  As_strength_men  Def_strength_men  \
# 0              NaN        NaN         160000.0           80000.0
# 1              NaN        NaN          59800.0           36000.0
# 2              NaN        NaN        1504000.0         1600000.0
# 3              NaN        NaN           1100.0             693.0
# 4              NaN        NaN         200000.0          180000.0
# 5              NaN        NaN         230000.0          150000.0
# 6              NaN        NaN        1071000.0         1485000.0
# 7              NaN        NaN              NaN               NaN
# 8              NaN        NaN        4400000.0         5400000.0
# 9  Austria-Hungary        NaN          24500.0            3750.0
#
#    As_strength_guns  Def_strength_guns  Assaulter_losses  Defender_losses  \
# 0             600.0              300.0            5000.0           1638.0
# 1             400.0              280.0           25000.0          15000.0
# 2            4640.0             5000.0          165000.0         264680.0
# 3               NaN                NaN             137.0             41.0
# 4               NaN                NaN           18500.0           4785.0
# 5               NaN                NaN          170000.0          13873.0
# 6               NaN                NaN          263000.0         256000.0
# 7               NaN                NaN               NaN              NaN
# 8               NaN                NaN           58155.0          46765.0
# 9             142.0                NaN            3000.0            700.0
#
#       Outcome
# 0         win
# 1         win
# 2        loss
# 3         win
# 4        loss
# 5        loss
# 6         win
# 7        loss
# 8  indecisive
# 9         win

# %%
#Create list of Assaulters
assaulter_list = []

for elem in df['Assaulter'].unique():
    if type(elem) == str:
        assaulter_list.append(elem)
    else:
        continue

for elem in df['Assaulter_1'].unique():
    if type(elem) == str:
        assaulter_list.append(elem)
    else:
        continue
        
for elem in df['Assaulter_2'].unique():
    if type(elem) == str:
        assaulter_list.append(elem)
    else:
        continue

#Create list of Defenders
defender_list = []

for elem in df['Defender'].unique():
    if type(elem) == str:
        defender_list.append(elem)
    else:
        continue
        
for elem in df['Defender_1'].unique():
    if type(elem) == str:
        defender_list.append(elem)
    else:
        continue
        
for elem in df['Defender_1'].unique():
    if type(elem) == str:
        defender_list.append(elem)
    else:
        continue

# %%
#Create a list of participants 
participants = []

participants = set(assaulter_list + defender_list)

#How many times has been successfully carried out the attack
wins_at = []

for elem in participants:
    score = 0
    for row in df['Assaulter'][df['Outcome'] == 'win']:
        if elem in row:
            score +=1
        else:
            continue
    wins_at.append(score)

data = {'Assaulter': list(participants),
        'Win': wins_at}
attack_win = pd.DataFrame(data)

# %%
#How many times has been unsuccessfully carried out the attack
loss_at = []

for elem in participants:
    score = 0
    for row in df['Assaulter'][df['Outcome'] == 'loss']:
        if elem in row:
            score +=1
        else:
            continue
    loss_at.append(score)

data = {'Assaulter': list(participants),
        'Loss': loss_at}
attack_loss = pd.DataFrame(data)

# %%
#How many times has been successfully carried out protection
wins_pr = []

for elem in participants:
    score = 0
    for row in df['Defender'][df['Outcome'] == 'loss']:
        if elem in row:
            score +=1
        else:
            continue
    wins_pr.append(score)

data = {'Defender': list(participants),
        'Win': wins_pr}
protection_win = pd.DataFrame(data)

# %%
#How many times has been unsuccessfully carried out protection
loss_pr = []

for elem in participants:
    score = 0
    for row in df['Defender'][df['Outcome'] == 'win']:
        if elem in row:
            score +=1
        else:
            continue
    loss_pr.append(score)

data = {'Defender': list(participants),
        'Loss': loss_pr}
protection_loss = pd.DataFrame(data)

# %%
#Dictionary
data = {'attack_win': wins_at,
        'attack_loss': loss_at,
        'protection_win': wins_pr,
        'protection_loss': loss_pr, }

# Create a dataframe from the dictionary, indexed by a participant's name
battle_record = pd.DataFrame(data,index=participants)
battle_record
# Out:
#                   attack_loss  attack_win  protection_loss  protection_win
# Ottoman Empire              0           0                7               6
# Canada                      0           0                0               0
# New Zealand                 0           0                0               0
# Empire of Japan             0           0                0               0
# France                      2           2                0               0
# Russian Empire              1           0                2               0
# United States               0           0                0               0
# Bavaria                     0           0                0               0
# Austria-Hungary             2           1                3               2
# German Empire               0           7                8               7
# Belgium                     1           0                1               0
# Australia                   0           1                0               0
# India                       0           0                0               0
# British Empire              9          12                5               0
# Kingdom of Italy            2           2                1               0
# Newfoundland                0           0                0               0
# Bulgaria                    0           3                0               0
# Serbia                      0           1                2               2

# %%
# Count the total attacks
battle_record['total_attacks'] = battle_record['attack_win'] + battle_record['attack_loss']

# Count the total defends
battle_record['total_defends'] = battle_record['protection_win'] + battle_record['protection_loss']

# Count the total wins
battle_record['total_wins'] = battle_record['attack_win'] + battle_record['protection_win']

# Count the total losses
battle_record['total_loss'] = battle_record['attack_loss'] + battle_record['protection_loss']

# Create a total number of battles
battle_record['total_battles'] = battle_record['total_attacks'] + battle_record['total_defends']

# Create a win percentage score (total wins / total battles)
battle_record['win_percentage'] = battle_record['total_wins'] / battle_record['total_battles'] * 100

# Create a composite score (total number of wins minus total number of losses)
battle_record['composite_record'] = battle_record['total_wins'] - battle_record['total_loss']

battle_record
# Out:
#                   attack_loss  attack_win  protection_loss  protection_win  \
# Ottoman Empire              0           0                7               6
# Canada                      0           0                0               0
# New Zealand                 0           0                0               0
# Empire of Japan             0           0                0               0
# France                      2           2                0               0
# Russian Empire              1           0                2               0
# United States               0           0                0               0
# Bavaria                     0           0                0               0
# Austria-Hungary             2           1                3               2
# German Empire               0           7                8               7
# Belgium                     1           0                1               0
# Australia                   0           1                0               0
# India                       0           0                0               0
# British Empire              9          12                5               0
# Kingdom of Italy            2           2                1               0
# Newfoundland                0           0                0               0
# Bulgaria                    0           3                0               0
# Serbia                      0           1                2               2
#
#                   total_attacks  total_defends  total_wins  total_loss  \
# Ottoman Empire                0             13           6           7
# Canada                        0              0           0           0
# New Zealand                   0              0           0           0
# Empire of Japan               0              0           0           0
# France                        4              0           2           2
# Russian Empire                1              2           0           3
# United States                 0              0           0           0
# Bavaria                       0              0           0           0
# Austria-Hungary               3              5           3           5
# German Empire                 7             15          14           8
# Belgium                       1              1           0           2
# Australia                     1              0           1           0
# India                         0              0           0           0
# British Empire               21              5          12          14
# Kingdom of Italy              4              1           2           3
# Newfoundland                  0              0           0           0
# Bulgaria                      3              0           3           0
# Serbia                        1              4           3           2
#
#                   total_battles  win_percentage  composite_record
# Ottoman Empire               13       46.153846                -1
# Canada                        0             NaN                 0
# New Zealand                   0             NaN                 0
# Empire of Japan               0             NaN                 0
# France                        4       50.000000                 0
# Russian Empire                3        0.000000                -3
# United States                 0             NaN                 0
# Bavaria                       0             NaN                 0
# Austria-Hungary               8       37.500000                -2
# German Empire                22       63.636364                 6
# Belgium                       2        0.000000                -2
# Australia                     1      100.000000                 1
# India                         0             NaN                 0
# British Empire               26       46.153846                -2
# Kingdom of Italy              5       40.000000                -1
# Newfoundland                  0             NaN                 0
# Bulgaria                      3      100.000000                 3
# Serbia                        5       60.000000                 1

# %% [markdown]
# ### Analysis

# %%
#Top 10 most active assaulters
battle_record.sort_values('total_attacks', ascending=False).head(10)['total_attacks']
# Out:
# British Empire      21
# German Empire        7
# Kingdom of Italy     4
# France               4
# Austria-Hungary      3
# Bulgaria             3
# Australia            1
# Belgium              1
# Serbia               1
# Russian Empire       1
# Name: total_attacks, dtype: int64

# %%
#Top 10 most active defenders
battle_record.sort_values('total_defends', ascending=False).head(10)['total_defends']
# Out:
# German Empire       15
# Ottoman Empire      13
# Austria-Hungary      5
# British Empire       5
# Serbia               4
# Russian Empire       2
# Belgium              1
# Kingdom of Italy     1
# New Zealand          0
# Empire of Japan      0
# Name: total_defends, dtype: int64

# %%
#Top 10 most victorious participants
battle_record.sort_values('total_wins', ascending=False).head(10)['total_wins']
# Out:
# German Empire       14
# British Empire      12
# Ottoman Empire       6
# Austria-Hungary      3
# Bulgaria             3
# Serbia               3
# France               2
# Kingdom of Italy     2
# Australia            1
# Empire of Japan      0
# Name: total_wins, dtype: int64

# %%
#Top 10 most losing participants
battle_record.sort_values('total_loss', ascending=False).head(10)['total_loss']
# Out:
# British Empire      14
# German Empire        8
# Ottoman Empire       7
# Austria-Hungary      5
# Russian Empire       3
# Kingdom of Italy     3
# France               2
# Belgium              2
# Serbia               2
# Empire of Japan      0
# Name: total_loss, dtype: int64

# %%
#Participants with the best win percentage
battle_record.sort_values('win_percentage', ascending=False).head(75)['win_percentage'][battle_record['win_percentage'] != float('Inf')]
# Out:
# Australia           100.000000
# Bulgaria            100.000000
# German Empire        63.636364
# Serbia               60.000000
# France               50.000000
# Ottoman Empire       46.153846
# British Empire       46.153846
# Kingdom of Italy     40.000000
# Austria-Hungary      37.500000
# Russian Empire        0.000000
# Belgium               0.000000
# Canada                     NaN
# New Zealand                NaN
# Empire of Japan            NaN
# United States              NaN
# Bavaria                    NaN
# India                      NaN
# Newfoundland               NaN
# Name: win_percentage, dtype: float64
